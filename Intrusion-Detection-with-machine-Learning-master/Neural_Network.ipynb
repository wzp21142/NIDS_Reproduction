# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\anaconda3\envs\tf1\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('finalwormholeDataset.csv')

# %%
df.head()
# Out:
#    duration protocol  Plength  flag  Mlength  HoP  LifeTime      MsgType DSN  \
# 0  0.000000     AODV       84     0       28    0      2000  Route Reply   0
# 1  0.000978     ICMP       92    -1       28   -1        -1           -1  -1
# 2  0.028177     AODV       76     0       20   -1        -1  Route Error   0
# 3  0.001886     AODV       76     0       20   -1        -1  Route Error   0
# 4  0.001973     ICMP       92    -1       20   -1        -1           -1  -1
#
#    Sno  ...  land  Tmode  Neighbors  Hflow  AvgFlow  Lflow  AvgHopCount  \
# 0    0  ...     0      1          8   6367  1319.25      5      0.24832
# 1    0  ...     2      0          8   6367  1319.25      5      0.24832
# 2    1  ...     2      1          8   6367  1319.25      5      0.24832
# 3    1  ...     2      1          8   6367  1319.25      5      0.24832
# 4    2  ...     2      0          8   6367  1319.25      5      0.24832
#
#    failedConnection  Failed Rate   Label
# 0              2700    59.960027  normal
# 1              2700    59.960027  attack
# 2              2700    59.960027  normal
# 3              2700    59.960027  normal
# 4              2700    59.960027  attack
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (637862, 21)

# %%
df = df.sample(frac=1)

# %%
df.head()
# Out:
#         duration protocol  Plength  flag  Mlength  HoP  LifeTime      MsgType  \
# 470050  0.001099     ICMP       92    -1       28   -1        -1           -1
# 407125  0.000991     AODV       84     0       28    0      2000  Route Reply
# 251354  0.005915     ICMP       92    -1       20   -1        -1           -1
# 528548  0.001452     ICMP       92    -1       20   -1        -1           -1
# 52931   0.005731     ICMP       92    -1       28   -1        -1           -1
#
#        DSN  Sno  ...  land  Tmode  Neighbors  Hflow      AvgFlow  Lflow  \
# 470050  -1   11  ...     2      0         13   7682  1918.769231      2
# 407125   0    6  ...     0      1         12   6333  1546.083333      5
# 251354  -1   16  ...     2      0         14   7759  1416.428571      4
# 528548  -1    2  ...     2      0         14   7746  1624.142857     27
# 52931   -1    1  ...     2      0         13   6354  1830.000000    290
#
#         AvgHopCount  failedConnection  Failed Rate   Label
# 470050     0.197173              4247    68.433774  attack
# 407125     0.232517              3999    60.821293  normal
# 251354     0.186595              4556    69.324407  attack
# 528548     0.192727              4213    58.351801  attack
# 52931      0.214960              4502    62.632165  attack
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (637862, 21)

# %%
df.describe()
# Out:
#             duration        Plength           flag        Mlength  \
# count  637862.000000  637862.000000  637862.000000  637862.000000
# mean        0.014189      89.589435     110.839263      25.770104
# std         0.096779      32.584956    1133.951488      32.609399
# min         0.000000      66.000000      -1.000000      10.000000
# 25%         0.000999      84.000000      -1.000000      20.000000
# 50%         0.001229      92.000000      -1.000000      28.000000
# 75%         0.001830      92.000000       0.000000      28.000000
# max         0.938905    1104.000000   16384.000000    1048.000000
#
#                  HoP       LifeTime            Sno         Sindex  \
# count  637862.000000  637862.000000  637862.000000  637862.000000
# mean       -0.766843     404.101061       9.819489    1429.758499
# std         0.578324     980.532344       9.727308    1139.028021
# min        -1.000000      -1.000000       0.000000       0.000000
# 25%        -1.000000      -1.000000       4.000000     484.000000
# 50%        -1.000000      -1.000000       8.000000    1078.000000
# 75%        -1.000000      -1.000000      12.000000    2254.000000
# max         6.000000   14984.000000     125.000000    4095.000000
#
#                 land          Tmode      Neighbors          Hflow  \
# count  637862.000000  637862.000000  637862.000000  637862.000000
# mean        1.631633       0.251398      13.758746    7236.509479
# std         0.763185       0.433817       2.826686     645.978748
# min         0.000000       0.000000       8.000000    6142.000000
# 25%         2.000000       0.000000      12.000000    6634.000000
# 50%         2.000000       0.000000      14.000000    7260.000000
# 75%         2.000000       1.000000      15.000000    7759.000000
# max         2.000000       1.000000      20.000000    8194.000000
#
#              AvgFlow          Lflow    AvgHopCount  failedConnection  \
# count  637862.000000  637862.000000  637862.000000     637862.000000
# mean     1671.795566      61.917407       0.204938       4342.024985
# std       276.146268     107.105989       0.017860        699.159048
# min      1001.300000       1.000000       0.179579       2700.000000
# 25%      1483.150000       4.000000       0.190776       3741.000000
# 50%      1722.500000       5.000000       0.197682       4491.000000
# 75%      1918.769231      27.000000       0.216141       4733.000000
# max      2056.733333     303.000000       0.248320       5624.000000
#
#          Failed Rate
# count  637862.000000
# mean       62.910107
# std         4.434745
# min        56.927251
# 25%        59.463764
# 50%        62.595632
# 75%        68.344537
# max        72.685851

# %%
df.replace({'normal':0, 'attack':1 }, inplace = True)

# %%
plt.hist(df['Label'], bins='auto')
plt.ylabel('No of times')
plt.show()
print('No. of normals: ', len(df[df['Label']==0]))
print('No. of attacks: ', len(df[df['Label']==1]))
# Out:
# No. of normals:  152144
# No. of attacks:  485718

# %%
sns.set_style('darkgrid')
sns.distplot(df['Label'])
plt.show()
# Out:
# d:\anaconda3\envs\tf1\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for x in df.columns:
    print(x,' ',df[x].dtype)
# Out:
# duration   float64
# protocol   object
# Plength   int64
# flag   int64
# Mlength   int64
# HoP   int64
# LifeTime   int64
# MsgType   object
# DSN   object
# Sno   int64
# Sindex   int64
# land   int64
# Tmode   int64
# Neighbors   int64
# Hflow   int64
# AvgFlow   float64
# Lflow   int64
# AvgHopCount   float64
# failedConnection   int64
# Failed Rate   float64
# Label   int64

# %%
df.isnull().sum()
# Out:
# duration            0
# protocol            0
# Plength             0
# flag                0
# Mlength             0
# HoP                 0
# LifeTime            0
# MsgType             0
# DSN                 0
# Sno                 0
# Sindex              0
# land                0
# Tmode               0
# Neighbors           0
# Hflow               0
# AvgFlow             0
# Lflow               0
# AvgHopCount         0
# failedConnection    0
# Failed Rate         0
# Label               0
# dtype: int64

# %%
for column in df.columns:
    if(df[column].dtype=='object'):
        print(column)
# Out:
# protocol
# MsgType
# DSN

# %%
pd.unique(df['protocol'].values)
# Out:
# array(['ICMP', 'AODV', 'UDP'], dtype=object)

# %%
df.replace({'AODV':0, 'ICMP':1, 'UDP':2 }, inplace = True)

# %%
pd.unique(df['MsgType'].values)
# Out:
# array(['-1', 'Route Reply', 'Route Error', 'Route Reply Acknowledgment',
#        'Route Request'], dtype=object)

# %%
df.replace({'Route Reply':0, '-1':1, 'Route Error':2, 'Route Request':3, 'Route Reply Acknowledgment':4}, inplace = True)

# %%
pd.unique(df['DSN'].values)
# Out:
# array([1, '0', '2', '1', '3', '4', '1,0', '1,3', '0,0', '0,1', '1,1',
#        '0,3', '0,0,0', '2,0', '2,2', '0,2', '1,2'], dtype=object)

# %%
df['DSN'].describe()
# Out:
# count     637862
# unique        17
# top            1
# freq      441222
# Name: DSN, dtype: int64

# %%
df.drop(['DSN'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (637862, 20)

# %%
y = df['Label']
df.drop(['Label'], axis=1, inplace=True)
print('y-shape: ', y.shape)
print('x-shape: ', df.shape)
# Out:
# y-shape:  (637862,)
# x-shape:  (637862, 19)

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.33, random_state=42)

# %%
print('x-train: ', x_train.shape)
print('y-train: ', y_train.shape)
print('x-test: ', x_test.shape)
print('y-train: ', y_train.shape)
# Out:
# x-train:  (427367, 19)
# y-train:  (427367,)
# x-test:  (210495, 19)
# y-train:  (427367,)

# %% [markdown]
# ## Basic neural network

# %%
model = Sequential()
model.add(Dense(12, input_dim=19, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12)                240
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 353
# Trainable params: 353
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train,y_train, epochs=5)
# Out:
# Epoch 1/5
#  - ETA: 17s - loss: 3.7987 - acc: 0.7617
# Epoch 2/5
#  - ETA: 5s - loss: 3.8023 - acc: 0.7615
# Epoch 3/5
#  - ETA: 4s - loss: 3.8055 - acc: 0.7613
# Epoch 4/5
# 427367/427367 [==============================] - 69s 162us/step - loss: 3.8036 - acc: 0.7614
# Epoch 5/5
#  - ETA: 47s - loss: 3.7866 - acc: 0.7625

# %%
accuracy = model.evaluate(x_train, y_train)
print('Accuracy: train %.2f' % (accuracy[1]*100))
# Out:
#  - ETA: 10s
# Accuracy: train 76.14

# %%
accuracy = model.evaluate(x_test, y_test)
print('Accuracy: test %.2f' % (accuracy[1]*100))
# Out:
# 210495/210495 [==============================] - 11s 54us/step
# Accuracy: test 76.16

# %%
# Y_predict = model.predict(x_test)
# print(Y_predict)
# cm = np.array(confusion_matrix(y_test, Y_predict, labels=[0,1]))
# confusion = pd.DataFrame(cm, index = ['attack', 'normal'],
#                         columns = ['pred_attack','pred_normal'])
# confusion

# %% [markdown]
# ## Feature selection using pearson correlation

# %%
df['Label'] = y

# %%
df.shape
# Out:
# (637862, 20)

# %%
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor['Label'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# protocol    0.820096
# Tmode       0.844137
# Label       1.000000
# Name: Label, dtype: float64

# %%
X_new = x_train[['protocol','Tmode']]

# %%
X_new.shape
# Out:
# (427367, 2)

# %%
clf = Sequential()
clf.add(Dense(12, input_dim=2, activation='relu'))
clf.add(Dense(8, activation='relu'))
clf.add(Dense(1, activation='sigmoid'))

# %%
clf.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
clf.fit(X_new,y_train, epochs=1)
# Out:
# Epoch 1/1
#  - ETA: 34s - loss: 0.1696 - acc: 0.9380

# %%
accuracy = clf.evaluate(X_new, y_train)
print('Accuracy: train %.2f' % (accuracy[1]*100))
# Out:
#  - ETA: 1s
# Accuracy: train 94.24

# %%
X_new_test = x_test[['protocol','Tmode']]
X_new_test.shape
# Out:
# (210495, 2)

# %%
accuracy = clf.evaluate(X_new_test, y_test)
print('Accuracy: test %.2f' % (accuracy[1]*100))
# Out:
#  - ETA: 1s
# Accuracy: test 94.17

# %% [markdown]
# ## Feature selection using tree based method

# %%
ETC = ExtraTreesClassifier()
ETC.fit(x_train, y_train)
print(ETC.feature_importances_)
# Out:
# d:\anaconda3\envs\tf1\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.0078982  0.14281087 0.00638712 0.15300204 0.00913407 0.00514858
#  0.0274104  0.0704773  0.10193355 0.05946289 0.03660795 0.36553299
#  0.00100704 0.00209751 0.00445545 0.00167229 0.00134513 0.00169012
#  0.00192651]

# %%
ETC_model = SelectFromModel(ETC, prefit=True)
X_new = ETC_model.transform(x_train)
X_new.shape
# Out:
# (427367, 6)

# %%
clf2 = Sequential()
clf2.add(Dense(12, input_dim=6, activation='relu'))
clf2.add(Dense(8, activation='relu'))
clf2.add(Dense(1, activation='sigmoid'))

# %%
clf2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
clf2.fit(X_new,y_train, epochs=1)
# Out:
# Epoch 1/1
#  - ETA: 48s - loss: 0.3173 - acc: 0.9043

# %%
accuracy = clf2.evaluate(X_new, y_train)
print('Accuracy: train %.2f' % (accuracy[1]*100))
# Out:
# 427367/427367 [==============================] - 34s 80us/step
# Accuracy: train 97.14

# %%
X_new_test = ETC_model.transform(x_test)
X_new_test.shape
# Out:
# (210495, 6)

# %%
accuracy = clf2.evaluate(X_new_test, y_test)
print('Accuracy: test %.2f' % (accuracy[1]*100))
# Out:
#  - ETA: 4s
# Accuracy: test 97.10
